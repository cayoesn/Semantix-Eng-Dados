# %% [markdown]
# <h2>Projeto Final de Spark (Avançado) (Pendente)</h2>

# %%
# Não consegui entender a proposta de criar o mesmo dashboard do exercicio anterior, 
# com dados diferentes. Eu conseguiria nem que seja interpretar os dados
# e fazer um pouco sem o uso do elastic (Por que não consegui configurar ele).

# %%
import requests

# %%
# Busca os dados da API Elastic

url = "https://imunizacao-es.saude.gov.br/desc-imunizacao/_search"
username = "imunizacao_public"
password = "qlto5t&7r_@+#Tlstigi"
response = requests.get(url, auth=(username, password))
dataset = response.json()

# %%
dataset['hits']['hits']
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '4de6afee-1d2d-421c-ba78-1f17830f5ec7-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'BRANCA',
#    'estabelecimento_uf': 'AM',
#    'vacina_fabricante_referencia': 'Organization/00394544000851',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '130080',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'entered-in-error',
#    'paciente_dataNascimento': '1958-09-09',
#    'estabelecimento_municipio_codigo': '130080',
#    'paciente_endereco_nmMunicipio': 'BORBA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_uf': 'AM',
#    'estabelecimento_municipio_nome': 'BORBA',
#    'estabelecimento_valor': '5359244',
#    'paciente_id': '91503d331c1ae4fad4643b387c63e28867f33cd88fd3ad0f137b01360c004641',
#    'id_sistema_origem': '16341',
# ...
