# %% [markdown]
# <h2>Projeto Final de Spark (Avançado)</h2>

# %%
import requests

# %%
# Busca os dados da API Elastic

url = "https://imunizacao-es.saude.gov.br/desc-imunizacao/_search"
username = "imunizacao_public"
password = "qlto5t&7r_@+#Tlstigi"
response = requests.get(url, auth=(username, password))
dataset = response.json()

# %%
dataset['hits']['hits']
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'eea7ca01-9273-4dc6-a848-74de05b0dc0a-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'BRANCA',
#    'estabelecimento_uf': 'ES',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '320350',
#    'vacina_grupoAtendimento_codigo': '000203',
#    'status': 'final',
#    'paciente_dataNascimento': '1949-11-23',
#    'estabelecimento_municipio_codigo': '320350',
#    'paciente_endereco_nmMunicipio': 'MONTANHA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_uf': 'ES',
#    'estabelecimento_municipio_nome': 'MONTANHA',
#    'estabelecimento_valor': '2627965',
#    'paciente_id': '4a7627f1c7ee0259d9b4e5c397d78eb608661e91f24c3dd5fdc895b4a97d84d3',
#    'id_sistema_origem': '24294',
#    'data_importacao_rnds': '2022-04-20T18:49:37.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 70 a 74 anos',
#    'sistema_origem': 'VACINA E CONFIA ES',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': 'eea7ca01-9273-4dc6-a848-74de05b0dc0a-i0b0',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE MONTANHA',
#    'estalecimento_noFantasia': 'ESF 4 SEMUS',
#    'paciente_idade': 71,
#    'vacina_dataAplicacao': '2021-10-14T00:00:00.000Z',
#    'vacina_lote': 'FG3528',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '87',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '29890',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.433Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '81914b44-3c21-434d-bac5-f3a29c6f755d-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'AMARELA',
#    'estabelecimento_uf': 'BA',
#    'vacina_fabricante_referencia': 'Organization/149',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '290070',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1957-05-09',
#    'estabelecimento_municipio_codigo': '290070',
#    'paciente_endereco_nmMunicipio': 'ALAGOINHAS',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'paciente_endereco_uf': 'BA',
#    'estabelecimento_municipio_nome': 'ALAGOINHAS',
#    'estabelecimento_valor': '2487225',
#    'paciente_id': '8dd4a4ea16954fc12464926006ebbcb5f6e0707dfca900557fdcb7591ca97f2f',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T19:39:56.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': '81914b44-3c21-434d-bac5-f3a29c6f755d-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '04',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE ALAGOINHAS',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA LIRIO DOS VALES',
#    'paciente_idade': 64,
#    'vacina_dataAplicacao': '2022-02-10T00:00:00.000Z',
#    'vacina_lote': '219VCD286Z',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '85',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '48060',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.434Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'a39d13e9-f90c-48cd-aa04-f90e4addfa97-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'AMARELA',
#    'estabelecimento_uf': 'PE',
#    'vacina_fabricante_referencia': 'Organization/28290',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '261070',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1986-03-17',
#    'estabelecimento_municipio_codigo': '261070',
#    'paciente_endereco_nmMunicipio': 'PAULISTA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_uf': 'PE',
#    'estabelecimento_municipio_nome': 'PAULISTA',
#    'estabelecimento_valor': '6463541',
#    'paciente_id': '18dc94b385244bf50ef0ae2b15fcb7dacc806603593709c79015b68ee6ed042c',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T19:12:45.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': 'a39d13e9-f90c-48cd-aa04-f90e4addfa97-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '04',
#    'estabelecimento_razaoSocial': 'SECRETARIA DE SAUDE DO PAULISTA',
#    'estalecimento_noFantasia': 'SECRETARIA DE SAUDE DO PAULISTA',
#    'paciente_idade': 36,
#    'vacina_dataAplicacao': '2022-03-30T00:00:00.000Z',
#    'vacina_lote': 'FP7082',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '87',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '55680',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.407Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '3da59cdc-40a9-4a94-a533-1149a64d022b-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'BRANCA',
#    'estabelecimento_uf': 'PR',
#    'vacina_fabricante_referencia': 'Organization/149',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '411915',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1974-06-12',
#    'estabelecimento_municipio_codigo': '411915',
#    'paciente_endereco_nmMunicipio': 'PINHAIS',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'paciente_endereco_uf': 'PR',
#    'estabelecimento_municipio_nome': 'PINHAIS',
#    'estabelecimento_valor': '6857744',
#    'paciente_id': '7c2d0ec0aa31bff4ea479aa3e2319a8c409b532cf7341890f779d9ae3c51ce3c',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T18:32:21.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': '3da59cdc-40a9-4a94-a533-1149a64d022b-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE PINHAIS',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA ANA NERY',
#    'paciente_idade': 47,
#    'vacina_dataAplicacao': '2022-04-20T00:00:00.000Z',
#    'vacina_lote': '21OVCD305W',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '85',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '83325',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.563Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '1a91b616-82c4-4f56-b806-d8ffd6a6b755-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'AMARELA',
#    'estabelecimento_uf': 'CE',
#    'vacina_fabricante_referencia': 'JANSSEN-CILAG/51780468000268',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '230440',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'status': 'final',
#    'paciente_dataNascimento': '1995-04-03',
#    'estabelecimento_municipio_codigo': '230440',
#    'paciente_endereco_nmMunicipio': 'FORTALEZA',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_uf': 'CE',
#    'estabelecimento_municipio_nome': 'FORTALEZA',
#    'estabelecimento_valor': '2528754',
#    'paciente_id': 'ffee314c8b741450e3954fb7472f569a9dc52fdb5e5c7225def1bc7260b1a7c1',
#    'id_sistema_origem': '18921',
#    'data_importacao_rnds': '2022-04-19T15:00:00.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Outros',
#    'sistema_origem': 'Fastmedic - FastSaude',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': '1a91b616-82c4-4f56-b806-d8ffd6a6b755-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '04',
#    'estabelecimento_razaoSocial': 'SMS SECRETARIA MUNICIPAL DE SAUDE FORTALEZA',
#    'estalecimento_noFantasia': 'UAPS ANASTACIO MAGALHAES',
#    'paciente_idade': 27,
#    'vacina_dataAplicacao': '2022-04-19T00:00:00.000Z',
#    'vacina_lote': '205F21A',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '88',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'paciente_endereco_cep': '60420',
#    'vacina_categoria_codigo': '9',
#    '@timestamp': '2022-04-21T09:19:05.563Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'fd30816f-dfea-49fb-b5ed-3a70e02b1d3c-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'BRANCA',
#    'estabelecimento_uf': 'RN',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '240770',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'status': 'final',
#    'paciente_dataNascimento': '1969-08-18',
#    'estabelecimento_municipio_codigo': '240770',
#    'paciente_endereco_nmMunicipio': 'MONTANHAS',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_uf': 'RN',
#    'estabelecimento_municipio_nome': 'MONTANHAS',
#    'estabelecimento_valor': '2375052',
#    'paciente_id': 'eedf0bb67d81085462ba790189dc1901bdea82d19aec6c7b62a34e448773b816',
#    'id_sistema_origem': '17862',
#    'data_importacao_rnds': '2022-04-20T21:25:27.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Outros',
#    'sistema_origem': 'RN + Vacina',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': 'fd30816f-dfea-49fb-b5ed-3a70e02b1d3c-i0b0',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE MONTANHAS',
#    'estalecimento_noFantasia': 'UBS BOA ESPERANCA',
#    'paciente_idade': 52,
#    'vacina_dataAplicacao': '2022-04-20T00:00:00.000Z',
#    'vacina_lote': '204G21A',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '88',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'paciente_endereco_cep': '59198',
#    'vacina_categoria_codigo': '9',
#    '@timestamp': '2022-04-21T09:19:05.564Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'c7ba084a-ed6e-4bb4-9104-d38faf3a6f9a-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'estabelecimento_uf': 'RJ',
#    'vacina_fabricante_referencia': 'Organization/30587',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '330455',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1977-12-25',
#    'estabelecimento_municipio_codigo': '330455',
#    'paciente_endereco_nmMunicipio': 'RIO DE JANEIRO',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_uf': 'RJ',
#    'estabelecimento_municipio_nome': 'RIO DE JANEIRO',
#    'estabelecimento_valor': '6919626',
#    'paciente_id': '2a24a2ea1ba6d167eb867fafab96365b5c12f14629e7ad45b81c92e11c26b8fd',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T18:55:14.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': 'c7ba084a-ed6e-4bb4-9104-d38faf3a6f9a-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '99',
#    'estabelecimento_razaoSocial': 'SMS RIO CF SERGIO NICOLAU AMIN AP 32',
#    'estalecimento_noFantasia': 'SMS CF SERGIO NICOLAU AMIN AP 32',
#    'paciente_idade': 44,
#    'vacina_dataAplicacao': '2022-04-18T00:00:00.000Z',
#    'vacina_lote': '207H21A',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '88',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '20780',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.907Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '344eeefd-b875-450d-9820-f41c5c3870f5-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'BRANCA',
#    'estabelecimento_uf': 'PR',
#    'vacina_fabricante_referencia': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '410690',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1989-01-14',
#    'estabelecimento_municipio_codigo': '410690',
#    'paciente_endereco_nmMunicipio': 'CURITIBA',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_uf': 'PR',
#    'estabelecimento_municipio_nome': 'CURITIBA',
#    'estabelecimento_valor': '0016837',
#    'paciente_id': '60975788bc096d5403bf7d389c54e8a18825aaa270e8c2551492818930ad3134',
#    'id_sistema_origem': '19762',
#    'data_importacao_rnds': '2022-04-20T20:05:22.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'E-saúde Curitiba',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': '344eeefd-b875-450d-9820-f41c5c3870f5-i0b0',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE CURITIBA',
#    'estalecimento_noFantasia': 'UMS PINHEIROS',
#    'paciente_idade': 33,
#    'vacina_dataAplicacao': '2022-04-19T00:00:00.000Z',
#    'vacina_lote': '207H21A',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '88',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '82030',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.566Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '33e182af-0c92-4847-b490-e87086db5626-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'estabelecimento_uf': 'RO',
#    'vacina_fabricante_referencia': 'Organization/28290',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '110020',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1972-11-20',
#    'estabelecimento_municipio_codigo': '110020',
#    'paciente_endereco_nmMunicipio': 'PORTO VELHO',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_uf': 'RO',
#    'estabelecimento_municipio_nome': 'PORTO VELHO',
#    'estabelecimento_valor': '5695899',
#    'paciente_id': '9ad9d3e40661098d970ec6ef1106e6e9acebd84b28e77dd78a5bae536a28325d',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T19:46:31.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': '33e182af-0c92-4847-b490-e87086db5626-i0b0',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_racaCor_codigo': '99',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICPAL DE PORTO VELHO',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA SOCIALISTA',
#    'paciente_idade': 49,
#    'vacina_dataAplicacao': '2022-04-20T00:00:00.000Z',
#    'vacina_lote': 'FN2724',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '87',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': 'None',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.567Z',
#    'dt_deleted': None}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'aeff963f-0500-4b09-9d5e-632bfedfd136-i0b0',
#   '_score': 1.0,
#   '_source': {'paciente_racaCor_valor': 'AMARELA',
#    'estabelecimento_uf': 'MG',
#    'vacina_fabricante_referencia': 'Organization/30587',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'vacina_descricao_dose': 'Reforço',
#    'paciente_endereco_coIbgeMunicipio': '313630',
#    'vacina_grupoAtendimento_codigo': '000201',
#    'status': 'final',
#    'paciente_dataNascimento': '1983-09-08',
#    'estabelecimento_municipio_codigo': '313630',
#    'paciente_endereco_nmMunicipio': 'JOAO PINHEIRO',
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_uf': 'MG',
#    'estabelecimento_municipio_nome': 'JOAO PINHEIRO',
#    'estabelecimento_valor': '2759144',
#    'paciente_id': '2f52f1729dacdfb8f14edb3f9e0a0873a75d106d7ff23c76ce3ffbc539a11cf4',
#    'id_sistema_origem': '16341',
#    'data_importacao_rnds': '2022-04-20T19:36:14.000Z',
#    '@version': '1',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 18 a 64 anos',
#    'sistema_origem': 'Novo PNI',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'vacina_numDose': '38',
#    'paciente_endereco_coPais': '10',
#    'document_id': 'aeff963f-0500-4b09-9d5e-632bfedfd136-i0b0',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_racaCor_codigo': '04',
#    'estabelecimento_razaoSocial': 'PREF MUN DE JOAO PINHEIRO',
#    'estalecimento_noFantasia': 'UBS GERALDO RESENDE RURALMINAS PSF IX',
#    'paciente_idade': 38,
#    'vacina_dataAplicacao': '2022-04-20T00:00:00.000Z',
#    'vacina_lote': '208F21A',
#    'data_importacao_datalake': '2022-04-21T06:08:04.000Z',
#    'vacina_codigo': '88',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'paciente_endereco_cep': '38770',
#    'vacina_categoria_codigo': '2',
#    '@timestamp': '2022-04-21T09:19:05.567Z',
#    'dt_deleted': None}}]
